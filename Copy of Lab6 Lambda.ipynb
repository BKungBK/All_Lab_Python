# %% [markdown]
# เขียนฟังก์ชันยกกำลังโดยใช้ Lambda โดยรับค่า x, y และรีเทิร์นผลลัพธ์ของ x^y
# ```
# print(square(5, 2))  # Output: 25
# print(square(3, 2))  # Output: 9
# ```

# %%
square = lambda x, y: x ** y
# Out:
# 25
# 9

# %% [markdown]
# เขียนโปรแกรมแปลงค่าอุณหภูมิจาก Celcius เป็น Farenheit โดยใช้ lambda
#
#
# ```
# # ทดสอบฟังก์ชัน
# print(celsius_to_fahrenheit(0))    # Output: 32.0 (แปลง 0°C)
# print(celsius_to_fahrenheit(25))   # Output: 77.0 (แปลง 25°C)
# print(celsius_to_fahrenheit(100))  # Output: 212.0 (แปลง 100°C)
# ```

# %%
celsius_to_fahrenheit = lambda c : c*1.8 + 32
# Out:
# 77.0

# %% [markdown]
# เขียนฟังก์ชันlambda ชื่อ displacement รับค่า u, a, t เพื่อคำนวณ s ตามสูตรการเคลื่อนที่
#
#
# 𝑠
# =
# 𝑢
# 𝑡
# +
# 1/
# 2
# 𝑎
# 𝑡^
# 2
#
#   โดยที่:
#
# 𝑠
#  = ระยะทาง (displacement)
# 𝑢
#  = ความเร็วต้น (initial velocity)
# 𝑡
#  = เวลา (time)
# 𝑎
#  = ความเร่ง (acceleration)
#
#
# ```
# # ทดสอบฟังก์ชัน
# print(displacement(10, 5, 2))  # Output: 75.0 (สำหรับ u=10, t=5, a=2)
# print(displacement(0, 10, 9.8))  # Output: 490.0 (สำหรับ u=0, t=10, a=9.8)
# print(displacement(5, 3, 1))  # Output: 18.5 (สำหรับ u=5, t=3, a=1)
# ```

# %%
displacement = lambda u, t, a : u * t + 1/2 * a * t **2
print(displacement(5, 3, 1))
# Out:
# 19.5
