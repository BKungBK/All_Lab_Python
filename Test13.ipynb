# %% [markdown]
# โค้ดปัญญาอ่อน

# %%
pi = 3.14
area = 2*int(pi)*5
print(area)
print(type(area),"\n")

pi = 3.14
area = 2*float(pi)*5
print(area)
print(type(area))

x = "10"
print("\n",int(x) **2)
# Out:
# 30
# <class 'int'>
#
# 31.400000000000002
# <class 'float'>
#
#  100

# %%
_str = 'mo'
_str2 = "haha"
print(_str, _str2)
# Out:
# mo haha

# %%
name = "NuMuHAHAHA"
print(name[0])
print(name[8] , name[0])
print(name[0:10])
print(name[2:8])
print(name[0:])
print(name[:8])
# Out:
# N
# H N
# NuMuHAHAHA
# MuHAHA
# NuMuHAHAHA
# NuMuHAHA

# %%
a = "Hello"
b = "Python"
print("H" not in a)
# Out:
# False

# %%
name = "Alice"
age = 30
gpa = 3.99
print("%s is %d years old." % (name,age))
print("Her GPA is %f"%gpa)
print("{} is {} years old.".format(name,age))
print("{name} is {age} years old.".format(name=name,age=age))
print(f"{name} is {age} years old.")
# Out:
# Alice is 30 years old.
# Her GPA is 3.990000
# Alice is 30 years old.
# Alice is 30 years old.
# Alice is 30 years old.

# %%
num = 61
print('num = %c'%num)
# Out:
# num = =
