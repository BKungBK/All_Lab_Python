# %%
class Player:
  def __init__(self, id, name, gpt):
    self.__Id = id
    self.__name = name
    self.__Gpt = gpt

  def get_gpt(self):
    return self.__Gpt

  def get_id(self):
    return self.__Id

  def get_name(self):
    return self.__name

  def set_gpt(self, gpt):
    self.__Gpt = gpt

  def set_name(self, name):
    self.__name = name

  def set_id(self, id):
    self.__Id = id

# %%
p = Player(1,"assanee",3.50)
p._Player__name = "gee"
print(p.get_name())
# Out:
# gee
