# %% [markdown]
# **POKEMON FIGHT**
#
# >โปรแกรมนี้เป็นเกมสู้โปเกม่อนง่าย ๆ ระหว่างผู้เล่นกับศัตรูที่สุ่มมา ผู้เล่นจะได้ตั้งชื่อโปเกม่อนของตัวเอง พร้อมสุ่มค่า HP, Damage และธาตุให้ จากนั้นจะมีการสุ่มศัตรูที่มีค่า HP, Damage และธาตุเช่นกัน
#
# > ถ้าผู้เล่นอยากเพิ่มพลังโจมตี x3 ก็จะมีให้แก้โจทย์คณิต ถ้าตอบถูกจะได้บูสต์พลัง
#
# > ธาตุแต่ละตัวก็มีแพ้-ชนะกันตามกติกาที่กำหนด ใครเลือดหมดก่อนก็แพ้ไป
# ถ้าผู้เล่นชนะจะได้เป็นเจ้าของโลกไปเลย แต่ถ้าแพ้... ก็เป็นแค่ "loser" เท่านั้น!

# %%
import random
import time

pokemon = {
    "Player": {
        "name" : "",
        "Hp" : 0,
        "Damage": 0,
        "Element": ""
    },
    "Enemy": {
        "name" : "",
        "Hp" : 0,
        "Damage": 0,
        "Element": ""
    }
}

pokemon_element = ["ดิน","น้ำ","ลม","ไฟ","กล้ามอาจารย์ชน"]
enemy_name = ["อาจารย์ชน","Skibidi","มาเควีย","BEE","JUM",]
pokemon_skill = ["เบ่งกล้าม","กระโดดกัดคอ","นิพพาน","ตด","ปล่อยพลังธาตุ"]

print("* 。 • ˚ ˚ ˛ ˚ ˛ • 。* 。° 。* 。 • ˚ * 。 • ˚ ˚ ˛ ˚ ˛ \n    ◢◤◢◤◢◤◢◤◢◤◢◤◢◤◢◤◢◤◢◤◢◤")
print("          ยินดีต้อนรับเข้าสู่เกม\n          ⚔POKEMON FIGHT!⚔")
print("    ◢◤◢◤◢◤◢◤◢◤◢◤◢◤◢◤◢◤◢◤◢◤\n* 。 • ˚ ˚ ˛ ˚ ˛ • 。* 。° 。* 。 • ˚ * 。 • ˚ ˚ ˛ ˚ ˛ ")
print("◢◤ พิมพ์ Start เพื่อเริ่มโปรแกรม หรือ End เพื่อปิดโปรแกรม ◢◤")
start = input("⚔ >> ")

while start.lower() != "start":
    if start.lower() == "end":
        exit()
    print("พิมพ์ Start เพื่อเริ่มโปรแกรม หรือ End เพื่อปิดโปรแกรม")
    start = input("⚔ >> ")

pokemon["Player"]["name"] = input("◢◤ กรุณาใส่ชื่อโปเกม่อนของคุณ ⚔ >> ")
print("\n**************************************************")
print(">>>>>>>>> เริ่มสุ่ม Status <<<<<<<<<")
print("**************************************************")

def random_status(who,r,damage_min,damage_max):
    if who == "Enemy":
        pokemon["Enemy"]["name"] = random.choice(enemy_name)
        pokemon["Enemy"]["Hp"] = random.randint(150,300)
        pokemon["Enemy"]["Damage"] = random.randint(damage_min,damage_max)
        pokemon["Enemy"]["Element"] = random.choice(pokemon_element)
        print("\n----------------------------")
        print(f"ชื่อ : {pokemon['Enemy']['name']}\nเลือด : {pokemon['Enemy']['Hp']}\nพลังโจมตี : {pokemon['Enemy']['Damage']} หน่วย\nธาตุ : {pokemon['Enemy']['Element']}")
        print("----------------------------")

    delay_time = 0.1
    for i in range(6):
        if r == "hp":
            pokemon["Player"]["Hp"] = random.randint(100,200)
            print(f"Hp ของน้อง {pokemon['Player']['name']} คือ < {pokemon['Player']['Hp']} >")
        elif r == "damage":
            pokemon["Player"]["Damage"] = random.randint(damage_min,damage_max)
            print(f"Damage ของน้อง {pokemon['Player']['name']} คือ < {pokemon['Player']['Damage']} >")
        elif r == "element":
            pokemon["Player"]["Element"] = random.choice(pokemon_element)
            print(f"Element ของน้อง {pokemon['Player']['name']} คือ < {pokemon['Player']['Element']} >")
        time.sleep(delay_time)
        delay_time += 0.2
        if i == 5 and r == "hp":
            print(f"\nยินดีด้วยน้องได้เลือด {pokemon['Player']['Hp']} หน่วย ♪(´▽｀)\n")
        elif i == 5 and r == "damage":
            print(f"\nยินดีด้วยน้องได้พลังโจมตี {pokemon['Player']['Damage']} หน่วย ♪(´▽｀)\n")
        elif i == 5 and r == "element":
            print(f"\nยินดีด้วยน้องได้ธาตุ {pokemon['Player']['Element']} (╯▽╰ )\n")

def check_element(player_element, opponent_element):
    if player_element == "กล้ามอาจารย์ชน":
        print(f"ธาตุ {player_element} ชนะทุกธาตุ!")
        pokemon["Enemy"]["Damage"] *= 0.90
    elif player_element == opponent_element:
        print(f"ธาตุ เหมือนกัน!")
    elif player_element == "น้ำ" and opponent_element == "ไฟ":
        print(f"ธาตุ {player_element} ชนะธาตุ {opponent_element}!")
        pokemon["Enemy"]["Damage"] *= 0.90
    elif player_element == "ไฟ" and opponent_element == "ลม":
        print(f"ธาตุ {player_element} ชนะธาตุ {opponent_element}!")
        pokemon["Enemy"]["Damage"] *= 0.90
    elif player_element == "ลม" and opponent_element == "ดิน":
        print(f"ธาตุ {player_element} ชนะธาตุ {opponent_element}!")
        pokemon["Enemy"]["Damage"] *= 0.90
    elif player_element == "ดิน" and opponent_element == "น้ำ":
        print(f"ธาตุ {player_element} ชนะธาตุ {opponent_element}!")
        pokemon["Enemy"]["Damage"] *= 0.90
    else:
        print(f"ธาตุ {player_element} แพ้ธาตุ {opponent_element}. ลดดาเมจของผู้เล่นลง 10%!")
        pokemon["Player"]["Damage"] *= 0.90
    pokemon["Player"]["Damage"] = int(pokemon["Player"]["Damage"])
    pokemon["Enemy"]["Damage"] = int(pokemon["Enemy"]["Damage"])

def math_coke():
    num1 = random.randint(1, 100)
    num2 = random.randint(1, 100)

    operators = ['+', '-']
    operator = random.choice(operators)

    problem = f"{num1} {operator} {num2}"
    result_math = eval(problem)

    return problem,result_math

# สุ่ม Status
print("**************************************************")
print(">>>>>>>>> เริ่มสุ่ม HP <<<<<<<<<")
print("**************************************************")
random_status("","hp",0,0)
time.sleep(1)
print("**************************************************")
print(">>>>>>>>> เริ่มสุ่ม Damage <<<<<<<<<")
print("**************************************************")
random_status("","damage",10,40)
time.sleep(1)
print("**************************************************")
print(">>>>>>>>> เริ่มสุ่ม Element <<<<<<<<<")
print("**************************************************")
random_status("","element",0,0)
time.sleep(1)
print(f"\nʚ ︵‿︵‿︵꒰ All Status ꒱︵‿︵‿︵ ɞ\n┊__________________________________┊\n꒰ 💭 ꒱ Name : {pokemon['Player']['name']}\n꒰ 💭 ꒱ Hp : {pokemon['Player']['Hp']} หน่วย\n꒰ 💭 ꒱ Damage : {pokemon['Player']['Damage']} หน่วย\n꒰ 💭 ꒱ Element : {pokemon['Player']['Element']}\n__________________________________\n︶︶︶︶︶︶︶︶︶︶︶︶")

print("\n**************************************************")
print("◢◤ หากต้องการดำเนินการต่อพิมพ์ Go หรือ End เพื่อปิดโปรแกรม")
start_Fight = input("⚔ >> ")
while start_Fight.lower() != "go":
    if start_Fight.lower() == "end":
        exit()
    print("พิมพ์ Go หรือ End เพื่อปิดโปรแกรม")
    start_Fight = input("⚔ >> ")

print("\n##################")
print("คุณจะต้องสู้กับ!!!!!")
print("##################")
time.sleep(2)
random_status("Enemy","",10,50)

# เริ่มการต่อสู้
print("\n**************************************************")
print(">>>>> เริ่มการต่อสู้ <<<<<<")
print("**************************************************\n")
Drink = input("หากต้องการให้น้องดื่ม Coke เพื่อเพิ่มพลังโจมตี x3 ต้องตอบโจทย์คณิตให้ถูกต้อง!\nกรุณาพิมพ์ yes เพื่อดื่มหรือพิมพ์ no เพื่อไม่ดื่ม\n⚔ >> ")
if Drink.lower() == "yes":
    problem,result_math = math_coke()
    print(f"โจทย์ คือ {problem} = ?")
    result_player = int(input("คำตอบ คือ "))
    if result_player == result_math:
        pokemon["Player"]["Damage"] *= 3
        print("\n**************************************************")
        print(">>>>> คำตอบถูกต้อง! <<<<<<")
        print(f"น้อง {pokemon['Player']['name']} ได้พลังโจมตีขึ้นเป็น {pokemon['Player']['Damage']}\n")
        print("**************************************************\n")
    else:
        print("คำตอบผิดจ้า เสียใจด้วย\n")
time.sleep(1)
check_element(pokemon["Player"]["Element"],pokemon["Enemy"]["Element"])
time.sleep(2)

# ผลการต่อสู้
winner = ""
while pokemon["Player"]["Hp"] >= 0 or pokemon["Enemy"]["Hp"] >= 0:
    pokemon["Enemy"]["Hp"] -= pokemon["Player"]["Damage"]
    if pokemon["Enemy"]["Hp"] <= 0:
        print(f'\n========= ผลการต่อสู้ =========\n{pokemon["Player"]["name"]} {random.choice(pokemon_skill)}ใส่ {pokemon["Enemy"]["name"]}\n{pokemon["Enemy"]["name"]} เลือดหมดแล้ว {pokemon["Player"]["name"]} ชนะไปแบบใสๆ\n============================')
        winner = pokemon["Player"]["name"]
        break
    print(f'น้อง {pokemon["Player"]["name"]} {random.choice(pokemon_skill)}ใส่ {pokemon["Enemy"]["name"]}\n{pokemon["Enemy"]["name"]} เลือดเหลือ {pokemon["Enemy"]["Hp"]}\n')
    time.sleep(1)
    pokemon["Player"]["Hp"] -= pokemon["Enemy"]["Damage"]
    if pokemon["Player"]["Hp"] <= 0:
        print(f'\n========= ผลการต่อสู้ =========\n{pokemon["Enemy"]["name"]} {random.choice(pokemon_skill)}ใส่ {pokemon["Player"]["name"]}\n{pokemon["Player"]["name"]} เลือดหมดแล้ว {pokemon["Enemy"]["name"]} ชนะไปแบบใสๆ\n============================')
        winner = pokemon["Enemy"]["name"]
        break
    print(f'น้อง {pokemon["Enemy"]["name"]} ไม่ยอม {random.choice(pokemon_skill)}ใส่ {pokemon["Player"]["name"]}\n{pokemon["Player"]["name"]} เลือดเหลือ {pokemon["Player"]["Hp"]}\n')
if winner == pokemon["Player"]["name"]:
    print("  ∧,,,∧")
    print("(  ̳• · • ̳)")
    print("/    づ(ยินดีด้วยคุณชนะแล้ว!!)")
    print("ตอนนี้คุณเป็นเจ้าของโลกแล้วขอให้มีความสุขนะ")
else:
    print("คุณนี้มัน loser ตัวพ่อจริงๆ")
print("\n≽ ^ • ⩊ • ^ ≼\n➤ ทำการปิดโปรแกรมอัติโนมัติ")
exit()
# Out:
# * 。 • ˚ ˚ ˛ ˚ ˛ • 。* 。° 。* 。 • ˚ * 。 • ˚ ˚ ˛ ˚ ˛
#     ◢◤◢◤◢◤◢◤◢◤◢◤◢◤◢◤◢◤◢◤◢◤
#           ยินดีต้อนรับเข้าสู่เกม
#           ⚔POKEMON FIGHT!⚔
#     ◢◤◢◤◢◤◢◤◢◤◢◤◢◤◢◤◢◤◢◤◢◤
# * 。 • ˚ ˚ ˛ ˚ ˛ • 。* 。° 。* 。 • ˚ * 。 • ˚ ˚ ˛ ˚ ˛
# ◢◤ พิมพ์ Start เพื่อเริ่มโปรแกรม หรือ End เพื่อปิดโปรแกรม ◢◤
# ⚔ >> Start
# ◢◤ กรุณาใส่ชื่อโปเกม่อนของคุณ ⚔ >> Bkung
#
# **************************************************
# >>>>>>>>> เริ่มสุ่ม Status <<<<<<<<<
# **************************************************
# **************************************************
# >>>>>>>>> เริ่มสุ่ม HP <<<<<<<<<
# **************************************************
# Hp ของน้อง Bkung คือ < 173 >
# Hp ของน้อง Bkung คือ < 191 >
# Hp ของน้อง Bkung คือ < 149 >
# Hp ของน้อง Bkung คือ < 174 >
# Hp ของน้อง Bkung คือ < 166 >
# Hp ของน้อง Bkung คือ < 151 >
#
# ยินดีด้วยน้องได้เลือด 151 หน่วย ♪(´▽｀)
#
# **************************************************
# >>>>>>>>> เริ่มสุ่ม Damage <<<<<<<<<
# ...
