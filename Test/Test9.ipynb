# %%
f = open('foo.txt', 'w')
f.write('welcome to calculus\ncalculalus is ez like banana\n')
f.close()

# %%
lines = ['Welcome to Calculus\n','calculalus is ez like banana\n','grade = a\n']
f = open('foo2.txt', 'w')
f.writelines(lines)
f.close()

# %%
f = open('foo.txt', 'r')
str = f.read()
print(str)
f.seek(11, 0)
str2 = f.read(8)
print(str2)
f.close()
# Out:
# welcome to calculus
# calculalus is ez like banana
#
# calculus
