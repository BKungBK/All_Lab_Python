# %%
num = [1, 2, 3, 4, 5]
fruits = ["apple", "banana", "cherry"]
mix = [1, "apple", 3.14, True]

print(num[0:4])
print(fruits[0:2])
print(mix[0:1])
print(f" 1st fruit : {fruits[0]}\n 2nd fruist : {fruits[1]}\n 3rd fruit : {fruits[2]}")
# Out:
# [1, 2, 3, 4]
# ['apple', 'banana']
# [1]
#  1st fruit : apple
#  2nd fruist : banana
#  3rd fruit : cherry

# %%
ar = [["skibidi", 1, 2],[1 , 6 , 8]]

print(ar[0][0])
# Out:
# skibidi

# %%
Me = ["ไอโบ", 18, "Men"]
print(Me)
print("Me มีลูก :",len(Me))
My = ["Skibidi","skibidi"]
print(Me + My)
print((Me + My) * 4)
print(18 in Me)
# Out:
# ['ไอโบ', 18, 'Men']
# Me มีลูก : 3
# ['ไอโบ', 18, 'Men', 'Skibidi', 'skibidi']
# ['ไอโบ', 18, 'Men', 'Skibidi', 'skibidi', 'ไอโบ', 18, 'Men', 'Skibidi', 'skibidi', 'ไอโบ', 18, 'Men', 'Skibidi', 'skibidi', 'ไอโบ', 18, 'Men', 'Skibidi', 'skibidi']
# True

# %% [markdown]
# **แบบผิด**

# %%
person = ("วิษนุ" , 18 , "ขายตูด")
person[1] = 17
person[2] = "ขายไข่"
print(person)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-255d7c2d9e23> in <cell line: 2>()
#       1 person = ("วิษนุ" , 18 , "ขายตูด")
# ----> 2 person[1] = 17
#       3 person[2] = "ขายไข่"
#       4 print(person)
#
# TypeError: 'tuple' object does not support item assignment

# %%
person = ["วิษณุ" , 18 , "ขายตูด"]
person[1] = 17
person[2] = "ขายไข่"
print(person)
# Out:
# ['วิษนุ', 17, 'ขายไข่']

# %%
student = {
    "name" : "วิษณุ",
    "age" : "ให้ทาย",
    "major" : "ขายกี"
}
print(f'ชื่อ {student["name"]}\nอายุเท่าไหร {student["age"]} \nทำอาชีพอะไร {student["major"]}')
# Out:
# ชื่อ วิษณุ
# อายุเท่าไหร ให้ทาย
# ทำอาชีพอะไร ขายกี

# %%
major = input("นุอยากขายอะไร ")

print(f"นุอยาก {major}")

major = input("ทำมากี่ปีแล้ว ")
print(f"พรี่นุทำมาแล้ว {major} ปี")
# Out:
# นุอยากขายอะไร ขายมจ
# นุอยาก ขายมจ
# ทำมากี่ปีแล้ว 6
# พรี่นุทำมาแล้ว 6 ปี
