# %%
class Test:
  def __init__(self, name):
    self.name = name

  def __add__(self, other):
    return f"Hi! {self.name} and {other.name}"

t = Test("B")
T = Test("K")
print(t + T)
# Out:
# Hi! B and K
