# %%
x = 13
y = 9
while x > y:
  print(f'{x}>{y}')
  x = x-1
print("end")
# Out:
# 13>9
# 12>9
# 11>9
# 10>9
# end

# %%
count = 4
while count >= 0:
  print(f"{count} Hello")
  count -= 1
# Out:
# 4 Hello
# 3 Hello
# 2 Hello
# 1 Hello
# 0 Hello

# %%
x = 1
summation = 0
while x != 0:
  x = int(input("enter number : "))
  summation += x
print(f"Summation = {summation}")
# Out:
# enter number : 5
# enter number : 5
# enter number : 0
# Summation = 10

# %%
fs = ["a", "b", "d", "1", "2", "skibidi"]
for f in fs:
  print(f)
# Out:
# a
# b
# d
# 1
# 2
# skibidi

# %%
subject = "Pythoooon Programming"
count = 0
for letter in subject:
  if letter in "aeiou":
    count +=1
    print(f"{letter}",end=" ")
print(f"มีสระ {count} ตัว")
# Out:
# o o o o o a i มีสระ 7 ตัว
