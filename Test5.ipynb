# %%
b = [20.23, 21.28, 21.34, 23.08, 23.66, 23.93, 24.09, 24.47, 27.45, 27.95, 28.23, 28.25, 29.04, 29.13, 29.37, 29.41, 30.42, 32.07, 32.44, 32.45, 33.01, 33.23, 33.75, 34.43]
print(b.sort())
for i in range(len(b)):
  if i == 5:
    print(b[i])
  elif i == 11:
    print(b[i])
  elif i == 17:
    print(b[i])
# Out:
# [20.23, 21.28, 21.34, 23.08, 23.66, 23.93, 24.09, 24.47, 27.45, 27.95, 28.23, 28.25, 29.04, 29.13, 29.37, 29.41, 30.42, 32.07, 32.44, 32.45, 33.01, 33.23, 33.75, 34.43]
# 23.93
# 28.25
# 32.07
